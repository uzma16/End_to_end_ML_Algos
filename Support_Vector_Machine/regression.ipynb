# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_regression

# %%
X,y = make_regression(n_samples=1000,n_features=2,n_targets=1,noise=3.0)

# %%
pd.DataFrame(X)[0]
# Out:
# 0      0.552028
# 1      0.709081
# 2      0.075676
# 3      2.000441
# 4     -0.486158
#          ...
# 995   -1.814242
# 996    2.219498
# 997    0.193253
# 998    1.209238
# 999    0.393425
# Name: 0, Length: 1000, dtype: float64

# %%
sns.scatterplot(x=pd.DataFrame(X)[0],y=pd.DataFrame(X)[1],hue=y)
# Out:
# <AxesSubplot:xlabel='0', ylabel='1'>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=42)

# %%
from sklearn.svm import SVR
svr = SVR(kernel='linear')

# %%
svr.fit(X_train,y_train)
# Out:
# SVR(kernel='linear')

# %%
svr.coef_
# Out:
# array([[17.69005975, 55.99110996]])

# %%
y_pred = svr.predict(X_test)

# %%
y_pred
# Out:
# array([ -10.08949408,  -78.50446197,   42.89512159,   34.78838166,
#        -120.05796246, -107.74293614,   87.77863653,  -35.44735509,
#           3.78010829,   61.92439705,  -40.07404321,  -44.41768522,
#          44.03305645,  -18.42401646,   -8.89679188,  -29.99715297,
#         111.56181659,  -79.8438347 ,   69.94535416,   38.16598883,
#          20.37685104,  -38.04620597,  102.60640889,   31.76778782,
#         -15.81061384,  -87.55419055,   32.91498048,  -54.51779819,
#          -7.55536592,  -51.28652439,  -37.19668509,   20.62090429,
#          18.75510055,   21.33033424,   27.30758468,   60.88101442,
#         -43.97021703,   52.50662423,  -62.28105267,  106.94893448,
#         -35.11964712,  -75.08407386,    5.23256016,  -56.31008767,
#          -1.70721577,  -80.26798817,  -24.06829959,   70.63064363,
#          24.17328889,   -0.61647815,  -76.84935092,    1.66065009,
#         -11.6569608 ,   91.50723353,  -84.27278482,   61.76026544,
#          13.22831287,   66.38217672,   49.77264421, -125.78608581,
#         -58.93602064,   21.8207115 ,  -14.63794184,   89.93989418,
#          44.81049179,  -28.52630462,   81.84406184,    9.63580541,
#          38.93719627,   -8.58756306,   -2.83855034,   26.20021993,
#         -44.9538162 ,   26.66233015,   22.26223233,   94.61422292,
#         -33.90363013,  -15.45876756,   -9.24521848,   -3.30583034,
#          -5.72134519,  -64.56325856,   13.00573672,   82.02335801,
#          12.92462954, -146.69576178,  -37.93518421,  -74.66704677,
#          -1.61691579,   88.91120115,   58.11772105,  -69.58462615,
#         -21.51091825,   49.98293052,  -52.31230155,   36.92874855,
#           3.63096576,  -32.7445549 ,   -5.79493078,  -42.86206991,
#          13.69735585,  -56.67447264,  -57.5497042 ,  -72.80406788,
#         -34.28655495,  -10.46375282,   25.5073375 ,  -57.00633527,
#         -88.40981597,   15.52553821,  -29.58476511,    6.4984329 ,
#          -7.87169561,   25.36248395,   75.25123805,  -90.4099325 ,
#         -16.34159511,   64.58260774,   39.45723949, -119.94904922,
#          80.03356394,  -45.80261183,  -27.80892729,  -18.38770839,
#         -37.49536374,   21.68841639,   30.59746467,   14.85368483,
#         -31.03933276,   -4.7798464 ,   39.51978519,   37.94460186,
#          42.71505624,   62.06290366,  -28.33799314,  -27.49837324,
#          62.17842101,   21.81807487,  -38.51724546,   52.11948528,
#          43.31140016, -111.15909661,  -30.87346534,   26.61338833,
#          60.46106956,   55.57060255,  -11.00206153,   80.54929848,
#         -65.50533806,   -1.42385314, -106.18298643,  -19.09461038,
#         -41.58078169,   48.74549696,   49.58124368,   42.12398461,
#         -23.54473103,   79.11735131,   -7.06346493,  -58.64460821,
#          35.29530534,  -36.95593343,    3.93251503,   25.06006152,
#         166.92825202,  -12.16256274,   41.97322162,   -4.83768318,
#         -55.60733704,  -29.88216369,  -58.67247457,   48.53519123,
#        -104.67270091,   53.25486386,  -11.03244042,   13.09834219,
#         -80.65771014,   18.58549864,  -50.66119839,  123.47885543,
#        -125.08043153,  -16.43089883,   16.66212147,  -40.73922541,
#         114.92811995, -106.02939823,   27.81793677,   24.08218203,
#          28.56845547,  -43.56447755,  171.64017506,  -80.97046258,
#         -28.82162459,   35.50538321, -121.07697589,    0.461401  ,
#          -9.82773631,  -80.24887763,   -5.98247931,   37.92624048])

# %%
from sklearn.metrics import r2_score

# %%
print(r2_score(y_test,y_pred))
# Out:
# 0.9970505368687316

# %% [markdown]
# Hyperparameter Tuning with SVR
